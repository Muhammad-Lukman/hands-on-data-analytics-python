# %% [markdown]
# # Assignment 1 - NumPy: Fundamentals, Operations & Broadcasting
# ### Data Analytics in Python | Week 3, Classes 7 & 8
#
#
# ### Instructions
#
# - This assignment has **four parts** and **40 questions total** (40 marks).
# - Write your answer in the code cell directly below each question.
# - Do **not** delete or modify the question cells.
# - Use only the imports provided. Do **not** import pandas, sklearn, or scipy.
# - Every answer must be a runnable Python cell - no pseudocode.
# - Show all output with `print()`. Unlabelled output receives half marks.
#
# | Part | Title | Questions | Marks |
# |------|-------|-----------|-------|
# | A | Array Construction & Attributes | Q1–Q10 | 10 |
# | B | WHO Global Health Dataset | Q11–Q20 | 10 |
# | C | Operations, Broadcasting & Linear Algebra | Q21–Q30 | 10 |
# | D | Pakistan Crop Yield Dataset | Q31–Q40 | 10 |
#
# **Total: 40 marks**

# %% [markdown]
# ## How to install Numpy to your vscode or local environment?

# %%
#write installation code here

# %%
#RUN THIS CELL FIRST - imports and random seed
import numpy as np
import time

np.random.seed(42)   # do not change - ensures reproducible results
print('NumPy version:', np.__version__)
# Out:
# NumPy version: 1.26.4

# %% [markdown]
# ## Part A - Array Construction & Attributes
# *10 questions · 1 mark each*
#
# This part tests your ability to create arrays the right way, read their metadata,
# and understand the view/copy distinction - the three foundations of Class 7.

# %% [markdown]
# ### Q1 - Five ways to create an array (1 mark)
#
# Create **five** separate arrays using five different construction methods:
#
# | Array | Method | Values |
# |-------|--------|--------|
# | `a` | `np.array()` from a Python list | `[3, 1, 4, 1, 5, 9, 2, 6]` |
# | `b` | `np.arange()` | Even integers from 0 to 18 inclusive |
# | `c` | `np.linspace()` | 7 evenly spaced values from 0.0 to 1.0 |
# | `d` | `np.zeros()` | Shape (3, 4) with dtype `int16` |
# | `e` | `np.eye()` | 5×5 identity matrix |
#
# Print each array and its `dtype`.

# %%
# Q1 - your answer here

# %% [markdown]
# ### Q2 - Shape, ndim, size, nbytes (1 mark)
#
# Given the following array:
# ```python
# data = np.random.randint(0, 100, size=(6, 8, 3))
# ```
# Without running a loop, print:
# 1. print the `array` in data
# 2. `data.shape` and `also explain the shape in words`
# 3. `data.ndim`
# 4. `data.size` (total element count)
# 5. `data.nbytes` (total bytes in memory)
# 6. The `itemsize` of each element
#
# Then verify: `size × itemsize == nbytes`. Print `True` or `False`.

# %%
# Q2 - your answer here
data = np.random.randint(0, 100, size=(6, 8, 3))

# %% [markdown]
# ### Q3 - dtype choice and memory (1 mark)
#
# You are storing 10 million binary flags (values are only 0 or 1).
# Create the same array three times with different dtypes: `bool`, `int32`, `float64`.
#
# ```python
# flags_raw = np.random.randint(0, 2, size=10_000_000)
# ```
#
# For each dtype, print the `dtype` and `nbytes`.
# Finally, print how many times larger `float64` is compared to `bool`.
# Explain in words `what is the meaning of the number at the end of these data types` int32 and int64 and float64. How are these two impact memory?

# %%
# Q3 - your answer here
flags_raw = np.random.randint(0, 2, size=10_000_000)

# %% [markdown]
# ### Q4 - Indexing and slicing a 2D array (1 mark)
#
# ```python
# exam = np.array([
#     #S1  S2  S3  S4  S5  <--- Subjects
#     [72, 85, 91, 68, 79],   #Student1
#     [88, 54, 76, 95, 83],   #Student2
#     [61, 77, 82, 70, 90],   #Student3
#     [95, 88, 74, 66, 58],   #Student4
#     [43, 69, 88, 92, 75],   #Student5
# ])  # shape (5 students, 5 subjects)
# ```
#
# Using **a single indexing expression each**, extract:
# 1. The score of student 2 (row index 1) in subject 3 (col index 2)
# 2. All scores of student 4 (last-but-one row)
# 3. All scores in subject 1 (first column)
# 4. The 3×3 block in the top-left corner
# 5. Every other student (rows 0, 2, 4), all subjects - using step slicing

# %%
# Q4 - your answer here
exam = np.array([
    [72, 85, 91, 68, 79],
    [88, 54, 76, 95, 83],
    [61, 77, 82, 70, 90],
    [95, 88, 74, 66, 58],
    [43, 69, 88, 92, 75],
])

# %% [markdown]
# ### Q5 - Views vs copies (1 mark)
#
# ```python
# temps = np.array([36.5, 37.2, 38.9, 36.8, 39.1, 37.5])
# ```
#
# **Part A - The view trap:**
# Create `high = temps[2:5]`. Modify `high[0] = 99.0`.
# Print `temps`. Explain in a comment why `temps` changed.
#
# **Part B - Breaking the link:**
# Reset `temps` to its original values. Now create a **genuine copy** `safe = temps[2:5].copy()`.
# Modify `safe[0] = 99.0`. Print both `temps` and `safe`.
# Explain in a comment why `temps` is unchanged this time.
#
# **Part C - Verification:**
# Use `np.shares_memory()` to confirm Part A shares memory and Part B does not.

# %%
# Q5 - your answer here
temps = np.array([36.5, 37.2, 38.9, 36.8, 39.1, 37.5])

# %% [markdown]
# ### Q6 - Boolean masking (1 mark)
#
# ```python
# bp = np.array([118, 142, 135, 128, 155, 112, 167, 139, 121, 148])
# ```
#
# Using boolean masks (no loops, no if/else), in **one expression each**:
# 1. Print all readings above 140 (hypertensive range)
# 2. Print all readings between 120 and 140 inclusive (borderline)
# 3. Count how many readings are below 120 (normal)
# 4. Replace all readings above 160 with `160` directly in the array
#    (simulate capping an impossible sensor value)
# 5. Print the percentage of hypertensive readings (> 140) rounded to 1 decimal place

# %%
# Q6 - your answer here
bp = np.array([118, 142, 135, 128, 155, 112, 167, 139, 121, 148])

# %% [markdown]
# ### Q7 - Fancy indexing and argsort (1 mark)
#
# ```python
# scores  = np.array([78, 95, 61, 88, 72, 99, 54, 83, 91, 67])
# names   = np.array(['Ali','Sara','Usman','Fatima','Bilal',
#                     'Ayesha','Hassan','Zara','Omar','Hina'])
# ```
#
# 1. Use `np.argsort()` to get the indices that would sort `scores` descending.
# 2. Print the top-3 students (name and score) using those indices.
# 3. Print the bottom-3 students (name and score).
# 4. Use fancy indexing to extract scores at positions `[0, 3, 5, 8]` simultaneously.
# 5. Using a boolean mask, print the names of all students who scored 80 or above.

# %%
# Q7 - your answer here
scores = np.array([78, 95, 61, 88, 72, 99, 54, 83, 91, 67])
names  = np.array(['Ali','Sara','Usman','Fatima','Bilal',
                   'Ayesha','Hassan','Zara','Omar','Hina'])

# %% [markdown]
# ### Q8 - Reshaping and stacking (1 mark)
#
# 1. Create `flat = np.arange(1, 25)`.
#    Reshape it into shape (2, 3, 4) in one line. Print the result and its shape.
#
# 2. Create two (4, 3) arrays:
#    ```python
#    week1 = np.random.randint(60, 100, (4, 3))
#    week2 = np.random.randint(60, 100, (4, 3))
#    ```
#    Stack them **vertically** with `np.vstack()` (result: 8×3) and
#    **horizontally** with `np.hstack()` (result: 4×6). Print both shapes.
#
# 3. Split the vertically-stacked result back into two equal arrays using `np.split()`.
#    Verify `np.array_equal(split_result[0], week1)` prints `True`.

# %%
# Q8 - your answer here
np.random.seed(42)
week1 = np.random.randint(60, 100, (4, 3))
week2 = np.random.randint(60, 100, (4, 3))

# %% [markdown]
# ### Q9 - Speed: NumPy vs Python loop (1 mark)
#
# Compute the **sum of squares** of 5,000,000 numbers using:
#
# **Method A - Python loop:**
# ```python
# nums = list(range(1, 5_000_001))
# ```
# Loop through `nums` and accumulate `total += x**2`.
#
# **Method B - NumPy vectorised:**
# ```python
# arr = np.arange(1, 5_000_001)
# ```
# Compute `(arr**2).sum()` in a single expression.
#
# Time both with `time.time()`. Print:
# - Time for each method (in milliseconds, 2 decimal places (`round()`))
# - The speedup factor (loop_time / numpy_time, integer)
# - Confirm both methods give the same answer

# %%
# Q9 - your answer here
import time

# %% [markdown]
# ### Q10 - linspace for scientific sampling (1 mark)
#
# A pharmacokinetics study measures drug concentration every 0.5 hours
# over a 12-hour window.
#
# 1. Create a `time_points` array using `np.linspace()` for hours 0.0 through 12.0
#    at 0.5-hour intervals (25 points). Print it.
#
# 2. The drug follows a simple decay model:
#    `concentration = 100 * np.exp(-0.3 * time_points)`
#    Compute and print the concentration at every time point.
#
# 3. Find and print:
#    - The time point where concentration first drops below 10.0 mg/L
#      (use boolean masking on `time_points`)
#    - The maximum concentration and when it occurs
#    - The average concentration over the full 12 hours

# %%
# Q10 - your answer here

# %% [markdown]
# ## Part B - WHO Global Health Dataset
# *10 questions · 1 mark each*
#
# The dataset below represents a simplified version of WHO global health indicators
# for 10 countries across 5 health metrics.
#
# **Columns (5 metrics):**
#
# 0. Life expectancy at birth (years)
# 1. Under-5 mortality rate (per 1,000 live births)
# 2. Adult obesity rate (%)
# 3. Hospital beds per 10,000 population
# 4. Health expenditure per capita (USD)
#
# **Rows (10 countries):**
# Pakistan, India, Bangladesh, Sri Lanka, Nepal, China, Iran, Turkey, Egypt, Nigeria
#
# Run the dataset cell below before answering questions Q11–Q20.

# %%
# DATASET - run this cell before Q11-Q20
np.random.seed(42)

countries = np.array(['Pakistan','India','Bangladesh','Sri Lanka','Nepal',
                      'China','Iran','Turkey','Egypt','Nigeria'])

metrics   = np.array(['Life_Exp','U5_Mortality','Obesity_Pct',
                      'Hospital_Beds','Health_Expenditure'])

# Shape: (10 countries, 5 metrics)
health = np.array([
    # LifeExp  U5Mort  ObesePct  Beds   Expend
    [ 67.3,    65.0,   27.0,    6.0,   43.0],   # Pakistan
    [ 69.7,    33.0,   22.9,    5.0,   75.0],   # India
    [ 72.6,    28.0,   20.1,    8.0,   88.0],   # Bangladesh
    [ 76.4,    8.0,    22.1,   40.0,  395.0],   # Sri Lanka
    [ 70.5,    32.0,   21.0,    3.0,   71.0],   # Nepal
    [ 76.9,    8.0,    19.3,   42.0,  757.0],   # China
    [ 75.5,    14.0,   25.1,   15.0,  524.0],   # Iran
    [ 77.7,    9.0,    32.1,   28.0,  496.0],   # Turkey
    [ 70.2,    22.0,   33.0,   15.0,  226.0],   # Egypt
    [ 54.7,    117.0,  8.9,    5.0,   83.0],    # Nigeria
], dtype=np.float64)

print('Dataset shape:', health.shape)
print('\nColumn:', metrics)
print('\nFirst 3 rows:')
print(health[:3])
# Out:
# Dataset shape: (10, 5)
#
# Column: ['Life_Exp' 'U5_Mortality' 'Obesity_Pct' 'Hospital_Beds'
#  'Health_Expenditure']
#
# First 3 rows:
# [[67.3 65.  27.   6.  43. ]
#  [69.7 33.  22.9  5.  75. ]
#  [72.6 28.  20.1  8.  88. ]]

# %% [markdown]
# ### Q11 - Descriptive statistics per metric (1 mark)
#
# For each of the 5 health metrics, compute and print:
# - Mean
# - Median
# - Standard deviation (round to 2 decimal places)
# - Minimum and maximum value
#
# Format the output as a table - one row per metric:
# ```
# Metric              Mean    Median    Std     Min      Max
# Life_Exp            71.15   70.10     5.74    54.70    77.70
# ...
# ```
# *Hint: `axis=0` collapses across countries (rows), giving one value per metric.*

# %%
# Q11 - your answer here

# %% [markdown]
# ### Q12 - Ranking countries by life expectancy (1 mark)
#
# 1. Extract the life expectancy column (column 0) as `life_exp`.
# 2. Use `np.argsort()` to rank countries from **highest to lowest** life expectancy.
# 3. Print the rankings as a numbered table:
#    ```
#    Rank 1: Turkey       - 77.7 years
#    Rank 2: China        - 76.9 years
#    ...
#    ```
# 4. Print the range (max − min) and comment on whether the gap is large or small
#    in the context of global health equity.

# %%
# Q12 - your answer here

# %% [markdown]
# ### Q13 - Boolean filtering across conditions (1 mark)
#
# Using **boolean masks only** (no loops):
#
# 1. Identify countries with life expectancy **above the dataset mean**.
#    Print their names and values.
#
# 2. Identify countries where **both** of the following hold:
#    - Under-5 mortality > 20 per 1,000
#    - Health expenditure < 100 USD per capita
#    These are countries facing the highest combined burden. Print their names.
#
# 3. Count how many countries have obesity rate **below** the dataset mean.
#    Print the count and the country names.

# %%
# Q13 - your answer here

# %% [markdown]
# ### Q14 - Column-wise normalisation with broadcasting (1 mark)
#
# Normalise the entire `health` matrix so each column (metric) is scaled to [0, 1]:
#
# $$\text{scaled}_{ij} = \frac{x_{ij} - \min_j}{\max_j - \min_j}$$
#
# 1. Compute `col_min` and `col_max` using `axis=0`. Print their shapes - both should be (5,).
# 2. Apply the formula in **one broadcasting expression** (no loops, no reshape).
# 3. Verify: `health_scaled.min(axis=0)` should be all zeros,
#    `health_scaled.max(axis=0)` should be all ones. Print these.
# 4. Print Pakistan's scaled profile (first row) and interpret what a value of 0.0 means.

# %%
# Q14 - your answer here

# %% [markdown]
# ### Q15 - Z-score standardisation per metric (1 mark)
#
# Compute z-scores for the `health` matrix column-wise:
#
# $$z_{ij} = \frac{x_{ij} - \mu_j}{\sigma_j}$$
#
# 1. Compute `col_mean` and `col_std` with `axis=0`. Print shapes (both should be `(5,)`).
# 2. Compute `health_z` using broadcasting.
# 3. Verify column means are ≈ 0 and column stds are ≈ 1.
#    Print both rounded to 10 decimal places - they will not be exactly 0 and 1 due to
#    floating-point arithmetic. That is expected.
# 4. Nigeria has the most extreme z-scores. Print Nigeria's full z-score profile
#    and identify which metric has the most extreme deviation and in which direction.

# %%
# Q15 - your answer here

# %% [markdown]
# ### Q16 - Composite Health Index (1 mark)
#
# Build a **Composite Health Index (CHI)** for each country using weighted metrics.
#
# The weights reflect relative importance (must sum to 1.0):
#
# | Metric | Weight |
# |--------|--------|
# | Life expectancy (scaled) | 0.30 |
# | Under-5 mortality (inverted: 1 - scaled) | 0.25 |
# | Obesity (inverted: 1 - scaled) | 0.10 |
# | Hospital beds (scaled) | 0.15 |
# | Health expenditure (scaled) | 0.20 |
#
# 1. Use the `health_scaled` matrix from Q14.
# 2. Invert the columns where **lower is better** (Under-5 mortality and Obesity):
#    `1.0 - health_scaled[:, col]`.
# 3. Define `weights = np.array([0.30, 0.25, 0.10, 0.15, 0.20])` and compute
#    `chi = (adjusted_health * weights).sum(axis=1)` - this uses broadcasting.
# 4. Print a ranked table from highest CHI (healthiest) to lowest. Round to 3 decimal places.

# %%
# Q16 - your answer here
# health_scaled from Q14 must be available

# %% [markdown]
# ### Q17 - Aggregation with axis (1 mark)
#
# Answer all questions using **axis-based aggregation** - no Python loops.
#
# 1. `axis=0` (across countries): which metric has the **highest variation** (std)?
#    Print the metric name and its std.
#
# 2. `axis=1` (across metrics): which country has the **highest mean** across all its
#    raw metric values? (Interpret with caution - raw scales differ, but the exercise
#    teaches axis=1.) Print the country name.
#
# 3. `keepdims=True`: compute the column means and subtract them from `health`
#    in a single broadcasting line. Print the shape of the result - it must be (10, 5).
#    This is the 'mean-centring' step used before PCA in machine learning.
#
# 4. Use `np.argmax(axis=0)` to find which country has the best value for
#    each metric. Print metric name → country name for all 5 metrics.

# %%
# Q17 - your answer here

# %% [markdown]
# ### Q18 - Correlation analysis with NumPy (1 mark)
#
# We want to know: does higher health spending correlate with better life expectancy?
#
# 1. Extract `life_exp` (column 0) and `expenditure` (column 4) as 1D arrays.
#
# 2. Compute Pearson correlation **manually** using NumPy (no scipy):
#    $$r = \frac{\sum (x_i - \bar{x})(y_i - \bar{y})}{\sqrt{\sum(x_i-\bar{x})^2 \cdot \sum(y_i-\bar{y})^2}}$$
#
# 3. Verify using `np.corrcoef(life_exp, expenditure)[0, 1]` - both must match.
#
# 4. Print the Pearson r rounded to 3 decimal places and write a one-line interpretation
#    in a comment: is the relationship positive or negative, strong or weak?

# %%
# Q18 - your answer here

# %% [markdown]
# ### Q19 - Detecting and replacing outliers (1 mark)
#
# The under-5 mortality column (column 1) has one country (Nigeria) with a very
# high value that skews analysis.
#
# 1. Compute the mean and standard deviation of column 1.
# 2. Define an outlier as any value more than **2 standard deviations** above the mean.
# 3. Use a boolean mask to identify and print the outlier country and its value.
# 4. Create `u5_capped`, a copy of column 1 where the outlier is replaced
#    by `mean + 2 * std` (Winsorisation - cap instead of delete).
# 5. Print the mean and std **before and after** capping. Comment on the change.

# %%
# Q19 - your answer here

# %% [markdown]
# ### Q20 - Full pipeline: group comparison (1 mark)
#
# Categorise the 10 countries into two groups based on **health expenditure**:
# - `high_spend`: expenditure ≥ 200 USD per capita
# - `low_spend`: expenditure < 200 USD per capita
#
# For **each group** and **each of the 5 metrics**, compute the group mean.
# Present the results as a comparison table:
#
# ```
# Metric              High-Spend Mean   Low-Spend Mean   Difference
# Life_Exp            ...               ...              ...
# U5_Mortality        ...               ...              ...
# ...
# ```
#
# Write two sentences in comments interpreting the most striking difference you observe.

# %%
# Q20 - your answer here

# %% [markdown]
# ## Part C - Operations, Broadcasting & Linear Algebra
# *10 questions · 1 mark each*
#
# This part tests the material from Class 8: ufuncs, axis-based aggregation,
# broadcasting rules, matrix operations, and reshaping.

# %% [markdown]
# ### Q21 - Element-wise operations and ufuncs (1 mark)
#
# ```python
# before = np.array([85.0, 90.0, 78.0, 110.0, 95.0])  # fasting glucose (mg/dL)
# after  = np.array([82.0, 87.0, 81.0,  98.0, 91.0])  # glucose after medication
# ```
#
# Using element-wise operations and ufuncs only (no loops):
# 1. `delta` = change after medication (after − before). Print.
# 2. `pct_change` = percentage change. Print rounded to 2 decimal places.
# 3. Apply `np.abs()` to delta. Print the absolute changes.
# 4. Use `np.clip()` to cap glucose values in `after` to the range [70, 100]. Print.
# 5. Simulate log-transform: `np.log(before)` and `np.log(after)`. Print both.

# %%
# Q21 - your answer here
before = np.array([85.0, 90.0, 78.0, 110.0, 95.0])
after  = np.array([82.0, 87.0, 81.0,  98.0, 91.0])

# %% [markdown]
# ### Q22 - Aggregation with axis (1 mark)
#
# A 4-patient, 7-day glucose monitoring matrix:
# ```python
# glucose = np.array([
#     [5.2, 5.8, 6.1, 5.5, 7.2, 6.8, 5.9],
#     [8.5, 9.1, 8.8, 7.9, 9.5, 8.3, 8.7],
#     [4.8, 5.0, 4.9, 5.3, 4.7, 5.1, 4.6],
#     [6.9, 7.3, 7.1, 8.2, 6.8, 7.5, 7.0],
# ])
# ```
#
# Using axis-based aggregation:
# 1. Mean glucose per patient (axis=1). Which patient has the highest average?
# 2. Mean glucose per day (axis=0). Which day had the highest average across all patients?
# 3. Overall max, min, and std (no axis - collapse to scalar).
# 4. Cumulative glucose per patient over the 7 days: `np.cumsum(axis=1)`. Print.
# 5. Using `keepdims=True`, subtract each patient's daily mean so readings are centred.

# %%
# Q22 - your answer here
glucose = np.array([
    [5.2, 5.8, 6.1, 5.5, 7.2, 6.8, 5.9],
    [8.5, 9.1, 8.8, 7.9, 9.5, 8.3, 8.7],
    [4.8, 5.0, 4.9, 5.3, 4.7, 5.1, 4.6],
    [6.9, 7.3, 7.1, 8.2, 6.8, 7.5, 7.0],
])

# %% [markdown]
# ### Q23 - Broadcasting: shapes and rules (1 mark)
#
# `Predict the` **`output shape`** **before running** each expression, then verify.
#
# ```python
# A = np.ones((4, 3))
# B = np.ones((3,))
# C = np.ones((4, 1))
# D = np.ones((1, 3))
# E = np.ones((4, 3, 2))
# F = np.ones((3, 2))
# ```
#
# For each expression:
# 1. `A + B`
# 2. `A + C`
# 3. `C + D`
# 4. `E + F`
# 5. `A + np.ones((5,))` - this one raises an error. Print the error message
#    using `try/except` and explain **in a comment** which broadcasting rule is violated.

# %%
# Q23 - your answer here
A = np.ones((4, 3))
B = np.ones((3,))
C = np.ones((4, 1))
D = np.ones((1, 3))
E = np.ones((4, 3, 2))
F = np.ones((3, 2))

# %% [markdown]
# ### Q24 - Broadcasting for data centering (1 mark)
#
# ```python
# patients = np.array([
#     [68.0, 1.72, 7.2, 128.0],  # weight(kg), height(m), glucose, bp_sys
#     [82.0, 1.68, 8.5, 142.0],
#     [55.0, 1.60, 5.1, 115.0],
#     [91.0, 1.80, 9.3, 155.0],
#     [73.0, 1.65, 6.8, 135.0],
#     [78.0, 1.74, 7.5, 140.0],
# ])
# ```
#
# 1. Compute `pop_mean` and `pop_std` across patients (axis=0). Print shapes.
# 2. Z-score normalise using one broadcasting expression. Print result shape - must be (6, 4).
# 3. Add a BMI column: `bmi = weight / height**2`. Use array slicing and broadcasting
#    to compute it for all 6 patients in one expression. Print the BMI values.
# 4. Concatenate the BMI column onto the normalised matrix: result shape must be (6, 5).

# %%
# Q24 - your answer here
patients = np.array([
    [68.0, 1.72, 7.2, 128.0],
    [82.0, 1.68, 8.5, 142.0],
    [55.0, 1.60, 5.1, 115.0],
    [91.0, 1.80, 9.3, 155.0],
    [73.0, 1.65, 6.8, 135.0],
    [78.0, 1.74, 7.5, 140.0],
])

# %% [markdown]
# ### Q25 - Matrix multiplication: the neural network forward pass (1 mark)
#
# You are simulating **one linear layer** of a neural network.
#
# ```python
# np.random.seed(7)
# X = np.random.randn(5, 4)         # 5 samples, 4 input features
# W = np.random.randn(4, 6)         # weight matrix: 4 inputs -> 6 neurons
# b = np.random.randn(6)            # bias vector: one per neuron
# ```
#
# 1. Compute `Z = X @ W + b`. Print `Z` and its shape (should be 5×6).
# 2. Confirm that `Z[0]` equals `np.dot(X[0], W) + b`. Print `True` or `False`.
# 3. Apply the ReLU activation: `A = np.maximum(0, Z)`. Print how many elements
#    were 'zeroed out' (were negative in Z but become 0 in A).
# 4. Add a second layer: `W2 = np.random.randn(6, 3)`, `b2 = np.random.randn(3)`.
#    Compute `Z2 = A @ W2 + b2`. Print its shape (should be 5×3).
# 5. Explain in a comment: why must the INNER dimensions match for `@`?
#    Use the shapes in this problem as your example.

# %%
# Q25 - your answer here
np.random.seed(7)
X = np.random.randn(5, 4)
W = np.random.randn(4, 6)
b = np.random.randn(6)

# %% [markdown]
# ### Q26 - Norms and distances (1 mark)
#
# ```python
# patient_a = np.array([5.2, 128.0, 22.1, 68.0])  # glucose, bp, bmi, weight
# patient_b = np.array([8.5, 145.0, 29.3, 84.0])
# patient_c = np.array([4.9, 112.0, 20.8, 61.0])
# ```
#
# 1. Compute the **L2 (Euclidean) distance** between patient_a and patient_b
#    `manually`: `np.sqrt(np.sum((a-b)**2))`. Print.
# 2. Verify with `np.linalg.norm(patient_a - patient_b)`. Print `True` if they match.
# 3. Find who is clinically **closer** to patient_a: patient_b or patient_c?
#    Print the two distances and the answer.
# 4. Compute the **cosine similarity** between patient_a and patient_b:
#    $\cos(\theta) = \frac{a \cdot b}{\|a\| \|b\|}$.
#    Print the result rounded to 4 decimal places.
# 5. Comment: why might Euclidean distance be misleading here without normalisation?

# %%
# Q26 - your answer here
patient_a = np.array([5.2, 128.0, 22.1, 68.0])
patient_b = np.array([8.5, 145.0, 29.3, 84.0])
patient_c = np.array([4.9, 112.0, 20.8, 61.0])

# %% [markdown]
# ### Q27 - Element-wise vs matrix multiply (1 mark)
#
# A very common mistake in NumPy is confusing `*` (element-wise) with `@` (matrix multiply).
#
# ```python
# A = np.array([[1, 2], [3, 4]])
# B = np.array([[5, 6], [7, 8]])
# ```
#
# 1. Compute `A * B` and `A @ B`. Print both and their shapes.
# 2. Are they the same? Print `True` or `False`.
# 3. Compute the **transpose** of A: `A.T`. Print it and its shape.
# 4. Compute `A.T @ A` (the Gram matrix). Print it.
# 5. Verify: `A.T @ A` is **symmetric** (equals its own transpose).
#    Print `np.array_equal(A.T @ A, (A.T @ A).T)`.

# %%
# Q27 - your answer here
A = np.array([[1, 2], [3, 4]])
B = np.array([[5, 6], [7, 8]])

# %% [markdown]
# ### Q28 - Fancy reshaping pipeline (1 mark)
#
# You receive a flat 1D sensor stream and must reshape it into a usable matrix.
#
# ```python
# sensor_stream = np.arange(1, 121)   # 120 readings
# ```
#
# 1. Reshape into `(24, 5)`: 24 hours × 5 sensors. Print shape.
# 2. From the (24, 5) matrix, extract **hours 8 through 16** (working hours) for
#    **sensors 1, 2, and 4 only** (zero-indexed). Print the result and its shape.
# 3. Flatten that result back to 1D using `.ravel()`. Print and confirm shape is (27,).
# 4. Compare `.ravel()` vs `.flatten()`: modify the ravel output and check
#    whether the original (24, 5) matrix changed. Print `True` if it changed.
# 5. What does this tell you about `.ravel()` vs `.flatten()`?
#    Write your answer in a comment.

# %%
# Q28 - your answer here
sensor_stream = np.arange(1, 121)

# %% [markdown]
# ### Q29 - Outer product and pairwise computation (1 mark)
#
# ```python
# concentrations = np.array([0.1, 0.5, 1.0, 2.0, 5.0])  # drug concentrations (mg/L)
# response_curve = np.array([1.2, 0.9, 0.7, 0.5, 0.2])  # measured inhibition (0–1)
# ```
#
# 1. Compute the **outer product** `np.outer(concentrations, response_curve)`.
#    Print its shape - should be (5, 5). Explain what each cell [i,j] represents.
# 2. Create a (5, 1) column vector and (1, 5) row vector from `concentrations`
#    using `[:, np.newaxis]` and `[np.newaxis, :]`. Print both shapes.
# 3. Compute the **pairwise absolute differences** between all concentration values:
#    `diff_matrix = np.abs(concentrations[:, None] - concentrations[None, :])`.
#    Print the matrix.
# 4. The diagonal of `diff_matrix` should be all zeros. Verify with `np.diag()`.

# %%
# Q29 - your answer here
concentrations = np.array([0.1, 0.5, 1.0, 2.0, 5.0])
response_curve = np.array([1.2, 0.9, 0.7, 0.5, 0.2])

# %% [markdown]
# ### Q30 - One-hot encoding with broadcasting (1 mark)
#
# One-hot encoding is fundamental in machine learning for converting categorical labels
# into a matrix representation that models can process.
#
# ```python
# labels = np.array([0, 2, 1, 0, 2, 1, 0, 1, 2, 0])  # class labels: 0=Normal, 1=Pre-diabetic, 2=Diabetic
# n_classes = 3
# ```
#
# 1. Use broadcasting to create the one-hot matrix in **one line** (no loops):
#    `(labels[:, None] == np.arange(n_classes)[None, :]).astype(int)`
#    Print the result and its shape (should be 10×3).
# 2. Verify: every row sums to exactly 1. Print `np.all(one_hot.sum(axis=1) == 1)`.
# 3. Count the samples in each class using `one_hot.sum(axis=0)`. Print.
# 4. Recover the original labels from the one-hot matrix using `np.argmax(axis=1)`.
#    Verify `np.array_equal(recovered, labels)` prints `True`.
# 5. Comment: why is one-hot preferred over using raw integer labels (0, 1, 2)
#    in neural network output layers?

# %%
# Q30 - your answer here
labels    = np.array([0, 2, 1, 0, 2, 1, 0, 1, 2, 0])
n_classes = 3

# %% [markdown]
# ## Part D - Pakistan Crop Yield Dataset
# *10 questions · 1 mark each*
#
# This dataset captures annual crop production data across **8 provinces/regions**
# of Pakistan for **4 major crops** over **5 years (2019–2023)**.
#
# **Shape: (8 regions, 4 crops, 5 years)** - a 3D array.
#
# **Rows (8 regions):** Punjab, Sindh, KPK, Balochistan, Gilgit-Baltistan, AJK, FATA, ICT
# **Slices/depth (4 crops):** Wheat, Rice, Cotton, Sugarcane
# **Pages (5 years):** 2019, 2020, 2021, 2022, 2023
#
# Yields are in **thousand tonnes**.
#
# Run the dataset cell below before answering Q31–Q40.

# %%
# DATASET - run this cell before Q31-Q40
np.random.seed(99)

regions = np.array(['Punjab','Sindh','KPK','Balochistan',
                    'Gilgit-Baltistan','AJK','FATA','ICT'])
crops   = np.array(['Wheat','Rice','Cotton','Sugarcane'])
years   = np.array([2019, 2020, 2021, 2022, 2023])

# Base yields (thousand tonnes) - reflects real relative magnitudes
base = np.array([
    # Wheat  Rice  Cotton  Sugarcane
    [21500,  3800,  9200,  68000],   # Punjab
    [ 4200,  2900,  3100,  19000],   # Sindh
    [  950,   120,    10,    420],   # KPK
    [ 1100,   200,   850,   1200],   # Balochistan
    [   80,    15,     0,     30],   # Gilgit-Baltistan
    [   45,    20,     0,     60],   # AJK
    [   30,    12,     2,     40],   # FATA
    [    5,     2,     1,     10],   # ICT
], dtype=np.float64)

# Build 3D array: (8, 4, 5) = (regions, crops, years)
# Add realistic year-to-year variation (±8% random fluctuation)
variation = 1.0 + np.random.uniform(-0.08, 0.08, (8, 4, 5))
yields = base[:, :, np.newaxis] * variation  # broadcasting: (8,4,1) * (8,4,5) -> (8,4,5)

# Simulate a drought year: 2022 (index 3) reduced wheat by 15% in Balochistan
yields[3, 0, 3] *= 0.85
# Flood year: 2022 Sindh rice down 20%
yields[1, 1, 3] *= 0.80

print('Dataset shape (regions, crops, years):', yields.shape)
print('\nRegions:', regions)
print('Crops:  ', crops)
print('Years:  ', years)
print('\nPunjab Wheat yields (2019-2023):', yields[0, 0, :].round(0))
# Out:
# Dataset shape (regions, crops, years): (8, 4, 5)
#
# Regions: ['Punjab' 'Sindh' 'KPK' 'Balochistan' 'Gilgit-Baltistan' 'AJK' 'FATA'
#  'ICT']
# Crops:   ['Wheat' 'Rice' 'Cotton' 'Sugarcane']
# Years:   [2019 2020 2021 2022 2023]
#
# Punjab Wheat yields (2019-2023): [22093. 21459. 22620. 19888. 22560.]

# %% [markdown]
# ### Q31 - Exploring a 3D array (1 mark)
#
# Understanding the shape before analysis prevents every indexing error.
#
# 1. Print the shape, ndim, size, and dtype of `yields`.
# 2. Extract and print **Punjab's** complete data: all 4 crops, all 5 years.
#    Shape should be (4, 5).
# 3. Extract **all regions' Wheat yield for 2023** (last year).
#    Shape should be (8,). Print with region names alongside.
# 4. Extract **Cotton yields for all regions, all years** - shape (8, 5). Print.
# 5. Extract the yield for `KPK`, `Rice`, `2021` as a single scalar.
#    Print it with appropriate label.

# %%
# Q31 - your answer here

# %% [markdown]
# ### Q32 - National totals with axis-based aggregation (1 mark)
#
# Use **axis-based aggregation** (no loops) for all questions.
#
# 1. Compute **total national production per crop per year**: sum across regions (axis=0).
#    Shape should be (4, 5). Print a formatted table: crops as rows, years as columns.
#
# 2. Compute **total production per region across all crops and years**:
#    sum across both crops (axis=1) and years (axis=2). Shape: (8,).
#    Which region is the largest producer? Print name and total.
#
# 3. Compute **average yield per crop** across all regions and all years.
#    Shape: (4,). Print crop name → average yield.
#
# 4. Find the single **highest-yielding (region, crop, year) combination**.
#    Use `np.argmax()` on the flat array, then `np.unravel_index()` to recover the 3D index.
#    Print: 'Highest yield: [region] [crop] [year] = [value] thousand tonnes'.

# %%
# Q32 - your answer here

# %% [markdown]
# ### Q33 - Year-on-year growth rate (1 mark)
#
# Agricultural planners need to know if production is growing or declining.
#
# 1. Compute the **year-on-year growth rate** for each region × crop pair:
#    `growth = (yields[:, :, 1:] - yields[:, :, :-1]) / yields[:, :, :-1] * 100`
#    Print the shape of `growth` - should be (8, 4, 4): 4 growth rates for 5 years.
#
# 2. Which (region, crop) pair had the **largest single-year growth** across all years?
#    Use `np.argmax()` + `np.unravel_index()`. Print the combination and the growth %.
#
# 3. Which (region, crop) pair had the **largest single-year decline**?
#    Use `np.argmin()`. Print combination and the decline %.
#
# 4. Compute average annual growth per crop across all regions and all year-pairs.
#    Which crop is growing fastest on average? Which is declining?

# %%
# Q33 - your answer here

# %% [markdown]
# ### Q34 - Broadcasting for target comparison (1 mark)
#
# The government has set **annual production targets** (thousand tonnes):
# ```python
# targets = np.array([22000.0, 4000.0, 10000.0, 72000.0])  # Wheat, Rice, Cotton, Sugarcane
# ```
#
# 1. Compute total national production per crop per year (sum across regions, axis=0).
#    Shape: (4, 5). Call it `national`.
#
# 2. Use broadcasting to compute `shortfall = targets[:, np.newaxis] - national`.
#    Print shape (should be 4×5). Positive = below target; Negative = above target.
#
# 3. Using a boolean mask, print which (crop, year) combinations **met or exceeded** the target.
#
# 4. For each crop, print how many of the 5 years the target was met.
#
# 5. Compute `achievement_pct = national / targets[:, np.newaxis] * 100`.
#    Print for each crop and year, rounded to 1 decimal place.

# %%
# Q34 - your answer here
targets = np.array([22000.0, 4000.0, 10000.0, 72000.0])

# %% [markdown]
# ### Q35 - Punjab dominance analysis (1 mark)
#
# Punjab is Pakistan's agricultural heartland. Quantify its contribution.
#
# 1. Extract Punjab's yields: `punjab = yields[0]` - shape (4, 5).
# 2. Compute national totals per crop per year: sum across regions (axis=0) - shape (4, 5).
# 3. Compute `punjab_share = punjab / national * 100`.
#    Print Punjab's share (%) for each crop in each year. Round to 1 decimal place.
# 4. Find: which crop has the highest average Punjab share? Print crop name and mean %.
# 5. In which year did Punjab's share of **wheat production** dip the lowest?
#    Print year and share %.

# %%
# Q35 - your answer here

# %% [markdown]
# ### Q36 - Drought impact detection (1 mark)
#
# We deliberately introduced a drought in Balochistan (2022) and floods in Sindh (2022).
# Can you detect them from the data alone?
#
# 1. For each region × crop pair, compute the **5-year mean** and **std** of yields.
#    Shapes both (8, 4).
# 2. Compute **z-scores** for every yield value:
#    `z = (yields - mean[:,:,None]) / std[:,:,None]` using broadcasting.
#    Print the z-score for Balochistan-Wheat-2022.
# 3. Flag all values with `z < -1.5` as **anomalously low** (potential drought/flood).
#    Print the (region, crop, year) of every anomaly detected.
# 4. Were both injected anomalies (Balochistan Wheat 2022, Sindh Rice 2022) detected?
#    Print `True` for each if it appeared in the anomaly list.

# %%
# Q36 - your answer here

# %% [markdown]
# ### Q37 - Rank regions by 2023 performance (1 mark)
#
# For strategic investment planning, the government wants regions ranked by
# total agricultural output in the most recent year (2023).
#
# 1. Extract all yields for 2023: `yields_2023 = yields[:, :, -1]` - shape (8, 4).
# 2. Compute each region's **total production in 2023** across all 4 crops: shape (8,).
# 3. Use `np.argsort()` to rank regions from **highest to lowest** total production.
# 4. Print a ranked table:
#    ```
#    Rank 1: Punjab     - 102,450.3 thousand tonnes
#    Rank 2: Sindh      -  29,214.7 thousand tonnes
#    ...
#    ```
# 5. Compute each region's **percentage share** of total national 2023 output.
#    Print alongside the ranking table.

# %%
# Q37 - your answer here

# %% [markdown]
# ### Q38 - Crop diversification index (1 mark)
#
# A region that produces only one crop is economically vulnerable.
# The **Herfindahl-Hirschman Index (HHI)** measures concentration:
#
# $$\text{HHI} = \sum_{c=1}^{4} \left(\frac{\text{yield}_c}{\text{total yield}}\right)^2$$
#
# HHI close to 1.0 = highly concentrated (bad); close to 0.25 = well diversified.
#
# 1. Compute each region's **total yield across all crops and all years**: shape (8,).
# 2. Compute each region's **per-crop total** across all years: shape (8, 4).
# 3. Compute crop **share** per region: `share = per_crop_total / total_all[:, None]`.
#    Verify each row sums to 1.0.
# 4. Compute HHI per region: `hhi = (share**2).sum(axis=1)`. Print.
# 5. Rank regions from most diversified (lowest HHI) to least diversified (highest HHI).
#    Which region is most at risk from a single-crop failure?

# %%
# Q38 - your answer here

# %% [markdown]
# ### Q39 - 5-year moving average trend (1 mark)
#
# A moving average smooths out short-term fluctuations to reveal trends.
# Since we only have 5 years, compute the overall trajectory using vectorised ops.
#
# 1. Compute national total per crop per year: `national = yields.sum(axis=0)` - shape (4, 5).
#
# 2. For each crop, compute the **year-by-year change** (2020-2019, 2021-2020, etc.):
#    `changes = national[:, 1:] - national[:, :-1]` - shape (4, 4).
#
# 3. Compute the **average annual change** per crop over the 5-year period.
#    Print: which crops are on an upward trend and which are declining?
#
# 4. Compute each crop's **coefficient of variation** (std/mean × 100) across the 5 years.
#    A high CV indicates an unstable, volatile crop. Print CV % per crop, ranked highest to lowest.
#
# 5. If the 2024 yield were extrapolated using `2023_yield + avg_annual_change`,
#    what would national production be per crop? Print the 2024 projections.

# %%
# Q39 - your answer here

# %% [markdown]
# ### Q40 - Full pipeline: food security score (1 mark)
#
# Design and compute a **Food Security Score** for each region.
# This is an open-ended question - your pipeline will be evaluated on correctness
# of the NumPy operations, not on the policy choice of weights.
#
# **Required steps:**
#
# 1. **Scale** each crop's 5-year total yield for each region to [0, 1] using min-max
#    across all 8 regions (axis=0 after summing over years).
#
# 2. **Weight** the crops. Wheat is the staple food in Pakistan. Use weights of your choice
#    but they must sum to 1.0. Define them as a NumPy array and document your reasoning
#    in a comment.
#
# 3. Compute the **weighted Food Security Score** for each region using a single
#    `np.dot()` or broadcasting expression. Shape: (8,).
#
# 4. Print a **final ranked table** from most food-secure to least food-secure:
#    ```
#    Food Security Ranking - Pakistan Regions 2019–2023
#    =====================================================
#    Rank 1: Punjab            Score: 0.918
#    Rank 2: Sindh             Score: 0.543
#    ...
#    ```
#
# 5. Write **3 sentences** (as Python comments) interpreting the ranking:
#    - Which region is most food-secure and why does that make sense?
#    - Which region is most vulnerable and what policy intervention might help?
#    - What are the limitations of this index (what factors does it NOT capture)?

# %%
# Q40 - your answer here
# Define your weights here (must sum to 1.0)
# weights = np.array([w_wheat, w_rice, w_cotton, w_sugarcane])

# %% [markdown]
# ## Submission Checklist
#
# Before submitting, confirm:
#
# - [ ] All 40 questions have a non-empty code cell below them
# - [ ] Every code cell produces labelled output (unlabelled output = half marks)
# - [ ] Q5, Q23, Q28, Q30, Q38, Q40 include at least one comment explaining a concept
# - [ ] The dataset cells (before Part B and before Part D) were run before their sections
#
# **Marking scheme:**
# - Correct output: 0.5 marks
# - Correct method (using the concept taught): 0.4 marks
# - Comment / interpretation where asked: 0.1 marks
#
# **Name:** ___________________________
#
# **Submission Date:** ___________________________
#
# *Good luck.*
