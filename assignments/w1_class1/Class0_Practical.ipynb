# %% [markdown]
# # Assignment 0 - Python Foundations for Data Analytics
#
# **Instructions**
#
# - Attempt all questions.
# - Use only the concepts covered in Class 0 and Class 1.
# - Do not use external libraries unless explicitly instructed.
# - Write your solution in the code cell provided after each question.

# %% [markdown]
# # Question 1 - Variable Swapping
#
# ## Problem
#
# Two laboratory samples have the following IDs:
#
# | Variable | Value |
# |---|---|
# | Sample A | S101 |
# | Sample B | S205 |
#
# Store both sample IDs in separate variables.
#
# Swap the values **without using a temporary variable**.
#
# Display:
# - Values before swapping
# - Values after swapping
#
# ### Pseudocode
#
# ```
# START
# Store both sample IDs
# Display original values
# Swap both variables
# Display swapped values
# END
# ```

# %%
# Write your solution here

# %% [markdown]
# # Question 2 - Employee Salary Analysis
#
# ## Problem
#
# A company has recorded the following information for an employee:
#
# | Variable | Value |
# |---|---:|
# | Employee Name | Fatima Noor |
# | Basic Salary (PKR) | 85000 |
# | Bonus (PKR) | 12000 |
# | Tax Rate | 10% |
#
# Store the information in appropriate variables.
#
# Calculate and display:
# - Gross Salary
# - Tax Amount
# - Net Salary
#
# ## Formula
#
# $$\mathrm{Gross\ Salary}=\mathrm{Basic\ Salary}+\mathrm{Bonus}$$
#
# $$\mathrm{Tax}=\mathrm{Gross\ Salary}\times\frac{10}{100}$$
#
# $$\mathrm{Net\ Salary}=\mathrm{Gross\ Salary}-\mathrm{Tax}$$
#
# ### Pseudocode
#
# ```
# START
# Store employee information
# Calculate gross salary
# Calculate tax amount
# Calculate net salary
# Display all results
# END
# ```

# %%
# Write your solution here

# %% [markdown]
# # Question 3 - Temperature Monitoring System
#
# ## Problem
#
# A laboratory recorded the body temperatures of five patients:
#
# | Patient | Temperature (°C) |
# |---|---:|
# | P1 | 36.8 |
# | P2 | 37.2 |
# | P3 | 38.5 |
# | P4 | 36.9 |
# | P5 | 39.1 |
#
# Store the temperature values in a Python list.
#
# Display:
# - Complete list
# - First temperature
# - Last temperature
# - Second temperature using positive indexing
# - Second last temperature using negative indexing
# - Total number of temperature readings
#
# ### Pseudocode
#
# ```
# START
# Create a list of temperatures
# Display the complete list
# Display the first element
# Display the last element
# Display the second element
# Display the second last element
# Display the total number of elements
# END
# ```

# %%
# Write your solution here

# %% [markdown]
# # Question 4 - Student Records Using a List
#
# ## Problem
#
# A teacher recorded the marks of five students in a quiz:
#
# | Student | Marks |
# |---|---:|
# | Student 1 | 78 |
# | Student 2 | 65 |
# | Student 3 | 91 |
# | Student 4 | 84 |
# | Student 5 | 73 |
#
# Store the marks in a Python list.
#
# Display:
# - Complete list
# - First student's marks
# - Last student's marks
# - First three marks using slicing
# - Last three marks using slicing
# - Total number of students
#
# ### Pseudocode
#
# ```
# START
# Create a list of marks
# Display complete list
# Display first and last elements
# Display slices
# Display total number of elements
# END
# ```

# %%
# Write your solution here

# %% [markdown]
# # Question 5 - Product Price Update
#
# ## Problem
#
# An online store maintains the following product prices:
#
# | Product | Price (PKR) |
# |---|---:|
# | Mouse | 1200 |
# | Keyboard | 2500 |
# | Monitor | 28000 |
# | Webcam | 4200 |
#
# Store the prices in a Python list.
#
# Perform the following tasks:
# - Display the original list
# - Update the price of the Keyboard to 2700
# - Append a new product price of 6500
# - Display the updated list
#
# ### Pseudocode
#
# ```
# START
# Create a list
# Display original list
# Modify one element
# Append one new value
# Display updated list
# END
# ```

# %%
# Write your solution here

# %% [markdown]
# # Question 6 - Country Information Using Tuples
#
# ## Problem
#
# Store the following information about Pakistan in a tuple:
#
# | Item |
# |---|
# | Pakistan |
# | Islamabad |
# | 241 Million |
# | PKR |
#
# Display:
# - Complete tuple
# - First element
# - Last element
# - Length of the tuple
#
# Attempt to modify one element of the tuple using `try-except` block and observe the result.
#
# (note: if there is an error print that error without commenting the line)
# ### Pseudocode
#
# ```
# START
# Create tuple
# Display tuple
# Access elements
# Attempt modification
# Observe output
# END
# ```

# %%
# Write your solution here

# %% [markdown]
# # Question 7 - Employee Information Using a Dictionary
#
# ## Problem
#
# A company has stored the following employee information:
#
# | Key | Value |
# |---|---|
# | Name | Ali Hassan |
# | Age | 29 |
# | Department | Finance |
# | Salary | 85000 |
#
# Create a dictionary using the information above.
#
# Display:
# - Complete dictionary
# - Employee Name
# - Department
#
# Update the salary to **90000** and display the updated dictionary.
#
# Add a new key named **City** with the value **Lahore**.
#
# Display the final dictionary.
#
# ### Pseudocode
#
# ```
# START
# Create dictionary
# Display dictionary
# Access required values
# Update salary
# Add city
# Display final dictionary
# END
# ```

# %%
# Write your solution here

# %% [markdown]
# # Question 8 - Blood Group Collection Using Sets
#
# ## Problem
#
# A hospital collected the following blood groups from patients:
#
# | Blood Groups |
# |---|
# | A+ |
# | O+ |
# | B+ |
# | A+ |
# | AB+ |
# | O+ |
# | B- |
#
# Create a Python list using the values above and then convert that list to set.
#
# Display:
# - Original data
# - Set after removing duplicate values automatically
# - Total number of unique blood groups
# - Whether **"AB+"** exists in the set.
#
# ### Pseudocode
#
# ```
# START
# Create a set
# Display the set
# Display total unique values
# Check membership of AB+
# Display result
# END
# ```

# %%
# Write your solution here

# %% [markdown]
# # Question 9 - Student Scholarship Eligibility
#
# ## Problem
#
# A university awards a scholarship when:
#
# - CGPA is **3.50 or above**
# - Attendance is **80% or above**
#
# Ask the user to enter:
#
# - Student CGPA
# - Attendance Percentage
#
# Display:
# - Entered values
# - Whether the student is eligible for the scholarship.
#
# Use logical operators in your solution.
#
# ### Pseudocode
#
# ```
# START
# Input CGPA
# Input attendance
# Check eligibility using logical operators
# Display the result
# END
# ```

# %%
# Write your solution here

# %% [markdown]
# # Question 10 - Weather Condition Analyzer
#
# ## Problem
#
# A weather station records the following information from the user:
#
# - Temperature (°C)
# - Is it raining? (True/False)
#
# Determine the weather condition using conditional statements.
#
# Display:
# - "Hot Day" if temperature is greater than 35°C.
# - "Pleasant Weather" if temperature is between 20°C and 35°C (inclusive).
# - "Cold Weather" if temperature is below 20°C.
# - Additionally display "Carry an Umbrella" if it is raining.
#
# ### Pseudocode
#
# ```
# START
# Input temperature
# Input raining status
# Determine weather condition using if-elif-else
# If raining, display umbrella message
# END
# ```

# %%
# Write your solution here

# %% [markdown]
# # Question 12 - Product Inventory Report
#
# ## Problem
#
# A warehouse stores the following products:
#
# | Product |
# |---|
# | Laptop |
# | Mouse |
# | Keyboard |
# | Monitor |
# | Printer |
#
# Store the product names in a Python list.
#
# Using a **for loop**, display:
# - Every product name.
#
# Then use **enumerate()** to display:
# - Serial Number
# - Product Name
#
# ### Pseudocode
#
# ```
# START
# Create product list
# Loop through the list
# Display every product
# Loop using enumerate()
# Display serial number and product name
# END
# ```

# %%
# Write your solution here

# %% [markdown]
# # Question 13 - Multiplication Table Generator
#
# ## Problem
#
# Ask the user to enter a positive integer.
#
# Using a **for loop** and the **range()** function, display the multiplication table from 1 to 10.
#
# Display:
# - Number × 1 = Result
# - Number × 2 = Result
# - ...
# - Number × 10 = Result
#
# ### Pseudocode
#
# ```
# START
# Input a number
# Loop from 1 to 10
# Calculate multiplication
# Display each result
# END
# ```

# %%
# Write your solution here

# %% [markdown]
# # Question 14 - Counting Even Numbers
#
# ## Problem
#
# Write a program to display all even numbers between **1 and 20** using a **for loop**.
#
# Display:
# - Every even number on a separate line.
#
# Use the **range()** function with an appropriate step size.
#
# ### Pseudocode
#
# ```
# START
# Loop from 2 to 20
# Increase by 2 each iteration
# Display every value
# END
# ```

# %%
# Write your solution here

# %% [markdown]
# # Question 15 - ATM PIN Verification
#
# ## Problem
#
# An ATM allows a maximum of **3 attempts** to enter the correct PIN.
#
# The correct PIN is:
#
# **1234**
#
# Ask the user to enter the PIN.
#
# If the correct PIN is entered:
# - Display **"Access Granted"** and stop the loop.
#
# Otherwise:
# - Display **"Incorrect PIN"**.
#
# If all attempts are used:
# - Display **"Account Locked"**.
#
# Use a **while loop**.
#
# ### Pseudocode
#
# ```
# START
# Initialize attempt counter (counter = 0)
# Repeat while attempts remain
# Input PIN
# If PIN is correct
# Display Access Granted
# Stop loop
# Otherwise
# Display Incorrect PIN
# Increase attempt counter
# If attempts finished
# Display Account Locked
# END
# ```

# %%
# Write your solution here

# %% [markdown]
# # Question 16 - Safe Division Calculator
#
# ## Problem
#
# Write a program that asks the user to enter:
#
# - Dividend
# - Divisor
#
# Calculate and display the result of the division.
#
# Use **try-except** to handle invalid input and division by zero.
#
# Display an appropriate message if an error occurs.
#
# ### Pseudocode
#
# ```
# START
# TRY
# Input dividend
# Input divisor
# Calculate division
# Display result
# EXCEPT
# Display appropriate error message
# END
# ```

# %%
# Write your solution here

# %% [markdown]
# # Question 17 - Monthly Sales Analysis
#
# ## Problem
#
# A shop recorded the following monthly sales (PKR):
#
# | Month | Sales |
# |---|---:|
# | January | 120000 |
# | February | 145000 |
# | March | 138000 |
# | April | 151000 |
# | May | 149000 |
#
# Store the sales values in a Python list.
#
# Using a **for loop**, display:
# - Month Number
# - Sales Amount
#
# Use **enumerate()** while displaying the results.
#
# ### Pseudocode
#
# ```
# START
# Create sales list
# Loop using enumerate()
# Display month number and sales amount
# END
# ```

# %%
# Write your solution here

# %% [markdown]
# # Question 18 - Library Book Inventory
#
# ## Problem
#
# A university library maintains the following books:
#
# | Book ID | Title |
# |---|---|
# | B101 | Python Programming |
# | B102 | Data Analytics |
# | B103 | Machine Learning |
# | B104 | Statistics |
#
# Create a dictionary using the Book ID as the key and the Title as the value.
#
# Display:
# - Complete dictionary
# - Title of Book ID **B102**
# - Add a new book with ID **B105** and title **Database Systems**
# - Display the updated dictionary
#
# ### Pseudocode
#
# ```
# START
# Create dictionary
# Display dictionary
# Access B102
# Add new key-value pair
# Display updated dictionary
# END
# ```

# %%
# Write your solution here

# %% [markdown]
# # Question 19 - Daily Step Counter
#
# ## Problem
#
# A fitness tracker records the following daily steps:
#
# | Day | Steps |
# |---|---:|
# | Monday | 6540 |
# | Tuesday | 8125 |
# | Wednesday | 7340 |
# | Thursday | 9020 |
# | Friday | 6895 |
#
# Store the values in a Python list.
#
# Using a **for loop**, calculate and display
# - each day's step count.
# - The **total steps** taken across all 5 days.
# - Print "Target Achieved!" for any individual day where steps were **above 8000**
#
# Then display the same information again using **enumerate()**.
#
# ### Pseudocode
#
# ```
# START
# Create list
# initialize total_steps = 0
# Loop through the list
# Display each value
# Add step count to total_steps,
# If step count > 8000,
# Display Target Achieved alert,
# Display final total_steps
# END
# ```

# %%
# Write your solution here
